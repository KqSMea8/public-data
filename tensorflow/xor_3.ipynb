# %%
# https://gist.github.com/pannous/2b8e2e05cf05a630b132
import tensorflow as tf
sess = tf.InteractiveSession()

# Desired input output mapping of XOR function:
x_ = [[0, 0], [0, 1], [1, 0], [1, 1]] # input
#labels=[0,      1,      1,      0]   # output =>
expect=[[1,0],  [0,1],  [0,1], [1,0]] # ONE HOT REPRESENTATION! 'class' [1,0]==0 [0,1]==1

# x = tf.Variable(x_)
x = tf.placeholder("float", [None,2]) #  can we feed directly?
y_ = tf.placeholder("float", [None, 2]) # two output classes

#啥作用
number_hidden_nodes = 20 # 20 outputs to create some room for negatives and positives

W = tf.Variable(tf.random_uniform([2, number_hidden_nodes], -.01, .01))
b = tf.Variable(tf.random_uniform([number_hidden_nodes], -.01, .01))
hidden  = tf.nn.relu(tf.matmul(x,W) + b) # first layer.

 # the XOR function is the first nontrivial function, for which a two layer network is needed.
W2 = tf.Variable(tf.random_uniform([number_hidden_nodes,2], -.1, .1))
b2 = tf.Variable(tf.zeros([2]))
hidden2 = tf.matmul(hidden, W2)#+b2

y = tf.nn.softmax(hidden2)


# Define loss and optimizer
cross_entropy = -tf.reduce_sum(y_*tf.log(y))
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(cross_entropy)

# Train
tf.global_variables_initializer().run()
for step in range(1000):
    feed_dict={x: x_, y_:expect } # feed the net with our inputs and desired outputs.
    e,a=sess.run([cross_entropy,train_step],feed_dict)
    if e<1:break # early stopping yay
    print("step %d : entropy %s" % (step,e) ) # error/loss should decrease over time


# Test trained model
correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1)) # argmax along dim-1
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float")) # [True, False, True, True] -> [1,0,1,1] -> 0.75.

print("accuracy %s"%(accuracy.eval({x: x_, y_: expect})))

learned_output=tf.argmax(y,1)
print(learned_output.eval({x: x_}))

#~ tensorboard --logdir="./tmp/graph/xor_3"
writer = tf.summary.FileWriter('./tmp/graph/xor_3',sess.graph)
writer.close()
# Out:
# step 0 : entropy 2.7721276
# step 1 : entropy 2.7714865
# step 2 : entropy 2.770639
# step 3 : entropy 2.769756
# step 4 : entropy 2.7670338
# step 5 : entropy 2.7667017
# step 6 : entropy 2.7648454
# step 7 : entropy 2.762302
# step 8 : entropy 2.760795
# step 9 : entropy 2.7588444
# step 10 : entropy 2.7544246
# step 11 : entropy 2.7531736
# step 12 : entropy 2.7486563
# step 13 : entropy 2.7434583
# step 14 : entropy 2.740234
# step 15 : entropy 2.7338252
# step 16 : entropy 2.7249465
# step 17 : entropy 2.7211077
# step 18 : entropy 2.7091403
# step 19 : entropy 2.6971984
# step 20 : entropy 2.6901517
# step 21 : entropy 2.6711583
# step 22 : entropy 2.6533036
# step 23 : entropy 2.6422791
# step 24 : entropy 2.6143045
# step 25 : entropy 2.5786304
# step 26 : entropy 2.5653853
# step 27 : entropy 2.5316577
# step 28 : entropy 2.4946935
# step 29 : entropy 2.4520426
# step 30 : entropy 2.4149508
# step 31 : entropy 2.34704
# step 32 : entropy 2.3076234
# step 33 : entropy 2.2476912
# step 34 : entropy 2.203624
# step 35 : entropy 2.1309402
# step 36 : entropy 2.0382767
# step 37 : entropy 1.9845462
# step 38 : entropy 1.9311917
# step 39 : entropy 1.9004375
# step 40 : entropy 1.7915425
# step 41 : entropy 1.7261903
# step 42 : entropy 1.711093
# step 43 : entropy 1.6022422
# step 44 : entropy 1.5161738
# step 45 : entropy 1.4833686
# step 46 : entropy 1.437108
# step 47 : entropy 1.3816648
# step 48 : entropy 1.3529792
# step 49 : entropy 1.25872
# step 50 : entropy 1.2231637
# step 51 : entropy 1.2225636
# step 52 : entropy 1.1509975
# step 53 : entropy 1.0939856
# step 54 : entropy 1.018672
# accuracy 1.0
# [0 1 1 0]
